# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

def f(u, x):
        return (u[1], -64*u[0])

y0 = [1/4, 1]
xs = np.linspace(0, 5, 5)
us = odeint(f, y0, xs)
ys = us[:, 0]

print(ys)
plt.xlabel("time")
plt.ylabel("amplitude")
plt.title("Solution of Free and Undamed case")
plt.plot(xs, ys, 'r-')
plt.grid()
plt.show()
# Out:
# [ 0.25       -0.27777051  0.21613872 -0.08494116 -0.0735953 ]
